# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import src.utils.metrics as metrics
import config.saveoursystem1 as save_our_system_config

CSV_PATHS = ["trials/saveoursystem1_trials_only_maintain.csv", "trials/saveoursystem1_trials_only_repair.csv", "trials/saveoursystem1_trials_only_replace.csv", "trials/saveoursystem1_trials_weighted_random.csv"]

# %%
pd.read_csv(CSV_PATHS[0], index_col=False, sep=";")
# Out:
#                                                Move_1  \
# 0   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 2 <-> 1', 'MA...
# 1   ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 2 <-> 1', 'M...
# 2   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 14 <-> 13', '...
# 3   ['MAINTAIN: 14 <-> 13', 'MAINTAIN: 2 <-> 3', '...
# 4   ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 4 <-> 5', 'M...
# 5   ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 11 <-> 7', ...
# 6   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 2 <-> 3', 'MA...
# 7   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 10 <-> 11', '...
# 8   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 6 <-> 5', '...
# 9   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 9 <-> 10', 'M...
# 10  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 4 <-> 5', 'M...
# 11        ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 11 <-> 7']
# 12  ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 10 <-> 14', ...
# 13  ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 9 <-> 10', '...
# 14  ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 14 <-> 13',...
# 15  ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 8 <-> 4', '...
# 16  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 2 <-> 3', 'M...
# 17  ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 2 <-> 3', 'MA...
# 18  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 10 <-> 14', ...
# 19  ['MAINTAIN: 14 <-> 13', 'MAINTAIN: 10 <-> 11',...
#
#                                                Move_2  \
# 0   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 2 <-> 1', '...
# 1   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 10 <-> 14', '...
# 2   ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 10 <-> 11', ...
# 3   ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 10 <-> 14', ...
# 4   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 2 <-> 3', 'MA...
# 5   ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 4 <-> 1', 'M...
# 6   ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 10 <-> 14', ...
# 7   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 12 <-> 8', ...
# 8   ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 13 <-> 12', ...
# 9   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 4 <-> 5', 'MA...
# 10  ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 10 <-> 11', '...
# 11  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 6 <-> 5', 'M...
# 12  ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 12 <-> 8', 'M...
# 13       ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 4 <-> 5']
# 14  ['MAINTAIN: 9 <-> 10', 'MAINTAIN: 7 <-> 6', 'M...
# 15                              ['MAINTAIN: 5 <-> 9']
# 16  ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 12 <-> 8', ...
# 17  ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 2 <-> 3', 'MA...
# 18  ['MAINTAIN: 9 <-> 10', 'MAINTAIN: 6 <-> 5', 'M...
# 19  ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 10 <-> 14',...
#
#                                                Move_3  \
# 0   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 8 <-> 4', 'MA...
# 1   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 2 <-> 1', 'MA...
# 2   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 7 <-> 3', 'MA...
# 3   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 8 <-> 4', 'MA...
# 4   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 7 <-> 3', 'MA...
# 5   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 7 <-> 6', 'MA...
# 6   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 13 <-> 12', '...
# 7   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 4 <-> 1', 'MA...
# 8   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 10 <-> 11', '...
# 9   ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 12 <-> 8', 'M...
# 10  ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 10 <-> 11', ...
# 11  ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 7 <-> 3', 'M...
# 12  ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 7 <-> 3', '...
# 13  ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 6 <-> 5', 'MA...
# 14  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 12 <-> 8', '...
# 15  ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 9 <-> 12', 'M...
# 16  ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 4 <-> 5', 'MA...
# 17  ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 9 <-> 12', ...
# 18  ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 2 <-> 1', 'MA...
# 19  ['MAINTAIN: 2 <-> 3', 'MAINTAIN: 8 <-> 4', 'MA...
#
#                                                Move_4  \
# 0   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 8 <-> 4', '...
# 1   ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 10 <-> 11', '...
# 2   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 2 <-> 3', 'MA...
# 3   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 7 <-> 6', 'MA...
# 4   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 7 <-> 6', 'MA...
# 5   ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 11 <-> 7', 'M...
# 6   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 5 <-> 9', 'MA...
# 7   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 6 <-> 5', 'MA...
# 8   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 14 <-> 13', '...
# 9       ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 12 <-> 8']
# 10  ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 10 <-> 14', '...
# 11  ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 4 <-> 1', 'M...
# 12  ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 11 <-> 7', '...
# 13  ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 7 <-> 6', 'MA...
# 14  ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 10 <-> 11', '...
# 15  ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 11 <-> 7', 'M...
# 16  ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 10 <-> 11', ...
# 17  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 9 <-> 10', '...
# 18  ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 9 <-> 10', 'M...
# 19  ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 10 <-> 14',...
#
#                                                Move_5  \
# 0   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 7 <-> 6', 'MA...
# 1   ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 7 <-> 3', '...
# 2   ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 2 <-> 3', 'M...
# 3   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 4 <-> 5', 'MA...
# 4   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 7 <-> 3', 'MA...
# 5   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 8 <-> 4', 'MA...
# 6   ['MAINTAIN: 14 <-> 13', 'MAINTAIN: 9 <-> 10', ...
# 7   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 10 <-> 14', '...
# 8                              ['MAINTAIN: 9 <-> 10']
# 9   ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 7 <-> 6', 'M...
# 10  ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 7 <-> 3', 'MA...
# 11  ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 10 <-> 11', '...
# 12  ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 2 <-> 3', 'MA...
# 13  ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 10 <-> 11', '...
# 14  ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 13 <-> 12', '...
# 15  ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 11 <-> 7', 'M...
# 16  ['MAINTAIN: 9 <-> 10', 'MAINTAIN: 6 <-> 5', 'M...
# 17        ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 7 <-> 6']
# 18  ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 10 <-> 11', '...
# 19  ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 4 <-> 5', 'MA...
#
#                                                Move_6  \
# 0   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 10 <-> 14', '...
# 1   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 10 <-> 11', '...
# 2   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 4 <-> 1', '...
# 3   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 4 <-> 5', 'MA...
# 4   ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 8 <-> 4', 'M...
# 5   ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 4 <-> 1', '...
# 6   ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 6 <-> 5', 'M...
# 7   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 14 <-> 13', '...
# 8   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 10 <-> 11', '...
# 9                              ['MAINTAIN: 12 <-> 8']
# 10  ['MAINTAIN: 14 <-> 13', 'MAINTAIN: 10 <-> 11',...
# 11  ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 9 <-> 10', 'M...
# 12  ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 10 <-> 14',...
# 13                              ['MAINTAIN: 6 <-> 5']
# 14  ['MAINTAIN: 9 <-> 10', 'MAINTAIN: 4 <-> 1', 'M...
# 15  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 7 <-> 6', 'M...
# 16                                                 []
# 17  ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 12 <-> 8', '...
# 18  ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 5 <-> 9', 'MA...
# 19  ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 9 <-> 12', 'M...
#
#                                                Move_7  \
# 0   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 2 <-> 1', '...
# 1   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 7 <-> 3', 'MA...
# 2   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 2 <-> 1', 'MA...
# 3   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 8 <-> 4', 'MA...
# 4   ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 7 <-> 6', '...
# 5   ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 10 <-> 11', '...
# 6   ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 5 <-> 9', 'M...
# 7   ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 7 <-> 6', '...
# 8                              ['MAINTAIN: 9 <-> 10']
# 9   ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 12 <-> 8', ...
# 10       ['MAINTAIN: 2 <-> 3', 'MAINTAIN: 10 <-> 11']
# 11  ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 6 <-> 5', '...
# 12                             ['MAINTAIN: 9 <-> 12']
# 13       ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 6 <-> 5']
# 14  ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 10 <-> 11',...
# 15     ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 14 <-> 13']
# 16  ['MAINTAIN: 9 <-> 10', 'MAINTAIN: 7 <-> 3', 'M...
# 17                             ['MAINTAIN: 9 <-> 12']
# 18  ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 7 <-> 3', 'MA...
# 19       ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 2 <-> 3']
#
#                                                Move_8  \
# 0   ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 8 <-> 4', 'MA...
# 1   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 4 <-> 5', 'MA...
# 2   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 9 <-> 12', 'M...
# 3   ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 4 <-> 1', '...
# 4   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 6 <-> 5', 'MA...
# 5   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 4 <-> 5', 'MA...
# 6   ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 14 <-> 13', '...
# 7   ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 2 <-> 3', 'MA...
# 8         ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 12 <-> 8']
# 9   ['MAINTAIN: 14 <-> 13', 'MAINTAIN: 9 <-> 12', ...
# 10  ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 10 <-> 11', '...
# 11  ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 9 <-> 12', '...
# 12  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 4 <-> 1', 'M...
# 13  ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 13 <-> 12',...
# 14  ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 4 <-> 1', '...
# 15                             ['MAINTAIN: 11 <-> 7']
# 16  ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 2 <-> 1', 'MA...
# 17                                                 []
# 18  ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 13 <-> 12',...
# 19        ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 11 <-> 7']
#
#                                                Move_9  \
# 0         ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 5 <-> 9']
# 1   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 14 <-> 13', '...
# 2   ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 9 <-> 12', '...
# 3   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 11 <-> 7', 'M...
# 4   ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 11 <-> 7', ...
# 5   ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 9 <-> 12', ...
# 6   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 7 <-> 3', 'MA...
# 7   ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 5 <-> 9', 'MA...
# 8                              ['MAINTAIN: 9 <-> 10']
# 9   ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 8 <-> 4', 'M...
# 10  ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 6 <-> 5', 'MA...
# 11                              ['MAINTAIN: 6 <-> 5']
# 12  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 4 <-> 1', 'M...
# 13  ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 9 <-> 12', 'M...
# 14                                                 []
# 15  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 7 <-> 6', 'M...
# 16  ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 6 <-> 5', 'MA...
# 17         ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 2 <-> 3']
# 18                            ['MAINTAIN: 13 <-> 12']
# 19                              ['MAINTAIN: 8 <-> 4']
#
#                                               Move_10  Score_1  Score_2  \
# 0   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 11 <-> 7', 'M...        3        4
# 1   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 14 <-> 13', '...        0        6
# 2   ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 2 <-> 3', 'M...        1        2
# 3         ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 2 <-> 1']        0        6
# 4   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 7 <-> 3', 'MA...        3        6
# 5   ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 2 <-> 1', 'M...        1        2
# 6   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 6 <-> 5', 'MA...        3        6
# 7                               ['MAINTAIN: 4 <-> 5']        1        2
# 8   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 9 <-> 10', 'M...        3        4
# 9        ['MAINTAIN: 14 <-> 13', 'MAINTAIN: 7 <-> 6']        1        2
# 10  ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 2 <-> 3', 'MA...        3        4
# 11  ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 9 <-> 12', ...        3        6
# 12         ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 8 <-> 4']        0        3
# 13        ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 7 <-> 3']        1        2
# 14  ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 11 <-> 7', 'M...        1        2
# 15  ['MAINTAIN: 14 <-> 13', 'MAINTAIN: 8 <-> 4', '...        1        1
# 16         ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 4 <-> 5']        3        4
# 17        ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 4 <-> 5']        3        3
# 18  ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 11 <-> 7', 'M...        3        6
# 19         ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 7 <-> 6']        3        6
#
#     Score_3  Score_4  Score_5  Score_6  Score_7  Score_8  Score_9  Score_10
# 0         4        4        4        4        4        4        4         4
# 1         9       10       10       10       10       10       10        10
# 2         3        3        3        3        3        3        3         3
# 3         7        8        8        8        8        8        8         8
# 4         9        9        9        9        9        9        9         9
# 5         3        4        5        6        7        8        9         9
# 6         7        8        9        9        9        9        9         9
# 7         3        3        3        3        3        3        3         3
# 8         5        5        5        5        5        5        5         5
# 9         3        3        3        3        3        3        3         3
# 10        5        5        5        5        5        5        5         5
# 11        9       12       15       18       19       19       19        19
# 12        3        3        3        3        3        3        3         3
# 13        3        3        3        3        3        3        3         3
# 14        3        3        3        3        3        3        3         3
# 15        1        1        1        1        1        1        1         1
# 16        5        5        5        5        5        5        5         5
# 17        3        3        3        3        3        3        3         3
# 18        9       12       13       14       14       14       14        14
# 19        7        8        9        9        9        9        9         9

# %%
datas = []
for csv_path in CSV_PATHS:
    data = pd.read_csv(csv_path, index_col=False, sep=";")
    data["method"] = "_".join(csv_path.split("_")[2:4]).strip()
    data["method"] = data["method"].str.replace(".csv", "", regex=False)
    datas.append(data)

# %%
merged_data = pd.concat(datas, ignore_index=True)
merged_data
# Out:
#                                                Move_1  \
# 0   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 2 <-> 1', 'MA...
# 1   ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 2 <-> 1', 'M...
# 2   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 14 <-> 13', '...
# 3   ['MAINTAIN: 14 <-> 13', 'MAINTAIN: 2 <-> 3', '...
# 4   ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 4 <-> 5', 'M...
# ..                                                ...
# 62  ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 4 <-> 5', '...
# 63       ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 10 <-> 14']
# 64  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 6 <-> 5', 'M...
# 65  ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 4 <-> 5', '...
# 66  ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 9 <-> 12', 'M...
#
#                                                Move_2  \
# 0   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 2 <-> 1', '...
# 1   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 10 <-> 14', '...
# 2   ['MAINTAIN: 12 <-> 8', 'MAINTAIN: 10 <-> 11', ...
# 3   ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 10 <-> 14', ...
# 4   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 2 <-> 3', 'MA...
# ..                                                ...
# 62  ['REPLACE: 10 <-> 11', 'MAINTAIN: 7 <-> 3', 'M...
# 63  ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 4 <-> 5', 'MA...
# 64  ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 14 <-> 13', '...
# 65  ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 7 <-> 6', '...
# 66  ['MAINTAIN: 2 <-> 3', 'MAINTAIN: 7 <-> 3', 'MA...
#
#                                                Move_3  \
# 0   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 8 <-> 4', 'MA...
# 1   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 2 <-> 1', 'MA...
# 2   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 7 <-> 3', 'MA...
# 3   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 8 <-> 4', 'MA...
# 4   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 7 <-> 3', 'MA...
# ..                                                ...
# 62  ['MAINTAIN: 2 <-> 3', 'MAINTAIN: 2 <-> 1', 'MA...
# 63  ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 13 <-> 12', '...
# 64  ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 10 <-> 14', ...
# 65  ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 10 <-> 14', '...
# 66  ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 13 <-> 12',...
#
#                                                Move_4  \
# 0   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 8 <-> 4', '...
# 1   ['MAINTAIN: 7 <-> 6', 'MAINTAIN: 10 <-> 11', '...
# 2   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 2 <-> 3', 'MA...
# 3   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 7 <-> 6', 'MA...
# 4   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 7 <-> 6', 'MA...
# ..                                                ...
# 62          ['REPLACE: 4 <-> 5', 'MAINTAIN: 6 <-> 5']
# 63  ['REPAIR: 12 <-> 8', 'REPAIR: 2 <-> 1', 'REPLA...
# 64  ['REPAIR: 7 <-> 3', 'REPLACE: 12 <-> 8', 'MAIN...
# 65  ['REPAIR: 9 <-> 12', 'REPAIR: 5 <-> 9', 'MAINT...
# 66  ['MAINTAIN: 13 <-> 12', 'REPAIR: 12 <-> 8', 'R...
#
#                                                Move_5  \
# 0   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 7 <-> 6', 'MA...
# 1   ['MAINTAIN: 10 <-> 11', 'MAINTAIN: 7 <-> 3', '...
# 2   ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 2 <-> 3', 'M...
# 3   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 4 <-> 5', 'MA...
# 4   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 7 <-> 3', 'MA...
# ..                                                ...
# 62                                ['REPAIR: 8 <-> 4']
# 63  ['MAINTAIN: 7 <-> 3', 'REPAIR: 2 <-> 1', 'REPA...
# 64  ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 14 <-> 13',...
# 65  ['MAINTAIN: 2 <-> 3', 'REPLACE: 4 <-> 5', 'REP...
# 66  ['REPLACE: 11 <-> 7', 'MAINTAIN: 13 <-> 12', '...
#
#                                                Move_6  \
# 0   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 10 <-> 14', '...
# 1   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 10 <-> 11', '...
# 2   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 4 <-> 1', '...
# 3   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 4 <-> 5', 'MA...
# 4   ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 8 <-> 4', 'M...
# ..                                                ...
# 62  ['REPLACE: 10 <-> 14', 'MAINTAIN: 2 <-> 1', 'M...
# 63  ['REPAIR: 4 <-> 1', 'REPLACE: 10 <-> 11', 'REP...
# 64  ['REPLACE: 11 <-> 7', 'MAINTAIN: 10 <-> 14', '...
# 65                                ['REPAIR: 7 <-> 3']
# 66                               ['REPLACE: 4 <-> 1']
#
#                                                Move_7  \
# 0   ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 2 <-> 1', '...
# 1   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 7 <-> 3', 'MA...
# 2   ['MAINTAIN: 7 <-> 3', 'MAINTAIN: 2 <-> 1', 'MA...
# 3   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 8 <-> 4', 'MA...
# 4   ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 7 <-> 6', '...
# ..                                                ...
# 62           ['MAINTAIN: 2 <-> 1', 'REPAIR: 7 <-> 6']
# 63  ['REPAIR: 9 <-> 12', 'REPAIR: 7 <-> 3', 'REPAI...
# 64  ['REPAIR: 5 <-> 9', 'REPAIR: 2 <-> 1', 'MAINTA...
# 65           ['REPAIR: 2 <-> 3', 'REPLACE: 11 <-> 7']
# 66                               ['REPAIR: 12 <-> 8']
#
#                                                Move_8  \
# 0   ['MAINTAIN: 6 <-> 5', 'MAINTAIN: 8 <-> 4', 'MA...
# 1   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 4 <-> 5', 'MA...
# 2   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 9 <-> 12', 'M...
# 3   ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 4 <-> 1', '...
# 4   ['MAINTAIN: 8 <-> 4', 'MAINTAIN: 6 <-> 5', 'MA...
# ..                                                ...
# 62                               ['REPLACE: 5 <-> 9']
# 63  ['MAINTAIN: 10 <-> 11', 'REPAIR: 10 <-> 14', '...
# 64  ['MAINTAIN: 10 <-> 14', 'REPLACE: 14 <-> 13', ...
# 65           ['REPAIR: 9 <-> 12', 'REPAIR: 12 <-> 8']
# 66                              ['REPLACE: 9 <-> 10']
#
#                                                Move_9  \
# 0         ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 5 <-> 9']
# 1   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 14 <-> 13', '...
# 2   ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 9 <-> 12', '...
# 3   ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 11 <-> 7', 'M...
# 4   ['MAINTAIN: 13 <-> 12', 'MAINTAIN: 11 <-> 7', ...
# ..                                                ...
# 62         ['REPAIR: 4 <-> 1', 'MAINTAIN: 10 <-> 14']
# 63  ['REPAIR: 12 <-> 8', 'REPAIR: 5 <-> 9', 'REPAI...
# 64             ['REPAIR: 2 <-> 1', 'REPAIR: 7 <-> 3']
# 65            ['REPAIR: 6 <-> 5', 'REPLACE: 4 <-> 5']
# 66                               ['REPAIR: 9 <-> 12']
#
#                                               Move_10  ...  Score_2  Score_3  \
# 0   ['MAINTAIN: 4 <-> 1', 'MAINTAIN: 11 <-> 7', 'M...  ...        4        4
# 1   ['MAINTAIN: 4 <-> 5', 'MAINTAIN: 14 <-> 13', '...  ...        6        9
# 2   ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 2 <-> 3', 'M...  ...        2        3
# 3         ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 2 <-> 1']  ...        6        7
# 4   ['MAINTAIN: 2 <-> 1', 'MAINTAIN: 7 <-> 3', 'MA...  ...        6        9
# ..                                                ...  ...      ...      ...
# 62  ['REPAIR: 12 <-> 8', 'REPAIR: 8 <-> 4', 'MAINT...  ...        6        9
# 63  ['REPLACE: 6 <-> 5', 'REPAIR: 4 <-> 5', 'REPAI...  ...        6        7
# 64  ['REPAIR: 6 <-> 5', 'REPAIR: 9 <-> 12', 'MAINT...  ...        6        7
# 65  ['REPAIR: 9 <-> 12', 'REPAIR: 2 <-> 1', 'REPAI...  ...        6        7
# 66            ['REPLACE: 7 <-> 6', 'REPAIR: 5 <-> 9']  ...        6        7
#
#     Score_4  Score_5  Score_6  Score_7  Score_8  Score_9  Score_10  \
# 0         4        4        4        4        4        4         4
# 1        10       10       10       10       10       10        10
# 2         3        3        3        3        3        3         3
# 3         8        8        8        8        8        8         8
# 4         9        9        9        9        9        9         9
# ..      ...      ...      ...      ...      ...      ...       ...
# 62       12       13       14       14       14       14        14
# 63        8        9       12       13       16       17        18
# 64       10       11       14       17       20       21        22
# 65        7        7        7        7        7        7         7
# 66        8        9       10       10       10       10        10
#
#              method
# 0     only_maintain
# 1     only_maintain
# 2     only_maintain
# 3     only_maintain
# 4     only_maintain
# ..              ...
# 62  weighted_random
# 63  weighted_random
# 64  weighted_random
# 65  weighted_random
# 66  weighted_random
#
# [67 rows x 21 columns]

# %%
merged_data["method"].unique()
# Out:
# array(['only_maintain', 'only_repair', 'only_replace', 'weighted_random'],
#       dtype=object)

# %%
moves_cols = ["Move_1","Move_2","Move_3","Move_4","Move_5","Move_6","Move_7","Move_8","Move_9","Move_10"]
scores_cols = ["Score_1","Score_2","Score_3","Score_4","Score_5","Score_6","Score_7","Score_8","Score_9","Score_10"]
merged_data[scores_cols] = merged_data[scores_cols].astype(int)
max_score_index = merged_data[scores_cols].iloc[:, -1].idxmax()

# %%
best_trial = merged_data.loc[max_score_index]
print("Best Trial Method: ", best_trial["method"])
print("Best Trial Score: ", best_trial[scores_cols].max())
for i in range(1, 11):
    print(f"Score_{i}", best_trial[f"Score_{i}"], f" -> Move_{i}: ", best_trial[f"Move_{i}"])
# Out:
# Best Trial Method:  weighted_random
# Best Trial Score:  22
# Score_1 3  -> Move_1:  ['MAINTAIN: 11 <-> 7', 'MAINTAIN: 6 <-> 5', 'MAINTAIN: 14 <-> 13', 'MAINTAIN: 2 <-> 1', 'MAINTAIN: 5 <-> 9', 'MAINTAIN: 4 <-> 1', 'MAINTAIN: 12 <-> 8', 'MAINTAIN: 10 <-> 14']
# Score_2 6  -> Move_2:  ['MAINTAIN: 5 <-> 9', 'MAINTAIN: 14 <-> 13', 'MAINTAIN: 13 <-> 12', 'MAINTAIN: 9 <-> 10', 'MAINTAIN: 4 <-> 1']
# Score_3 7  -> Move_3:  ['MAINTAIN: 9 <-> 12', 'MAINTAIN: 10 <-> 14', 'MAINTAIN: 4 <-> 1']
# Score_4 10  -> Move_4:  ['REPAIR: 7 <-> 3', 'REPLACE: 12 <-> 8', 'MAINTAIN: 9 <-> 10', 'MAINTAIN: 10 <-> 14', 'MAINTAIN: 14 <-> 13', 'MAINTAIN: 6 <-> 5']
# Score_5 11  -> Move_5:  ['MAINTAIN: 10 <-> 14', 'MAINTAIN: 14 <-> 13', 'REPAIR: 7 <-> 3']
# Score_6 14  -> Move_6:  ['REPLACE: 11 <-> 7', 'MAINTAIN: 10 <-> 14', 'REPAIR: 8 <-> 4']
# Score_7 17  -> Move_7:  ['REPAIR: 5 <-> 9', 'REPAIR: 2 <-> 1', 'MAINTAIN: 10 <-> 14']
# Score_8 20  -> Move_8:  ['MAINTAIN: 10 <-> 14', 'REPLACE: 14 <-> 13', 'REPAIR: 2 <-> 3']
# Score_9 21  -> Move_9:  ['REPAIR: 2 <-> 1', 'REPAIR: 7 <-> 3']
# Score_10 22  -> Move_10:  ['REPAIR: 6 <-> 5', 'REPAIR: 9 <-> 12', 'MAINTAIN: 14 <-> 13', 'MAINTAIN: 10 <-> 14', 'REPAIR: 12 <-> 8']
